# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
from torch.utils.data import TensorDataset, DataLoader
import matplotlib.pyplot as plt

labelName = ["bowl", "dog", "feel", "get", "I", "know", "must", "sick", "you", "zero"]
batchSize = 128
trainingRatio = 0.8
device = torch.device("cuda")

count = 0
rawDataSets = []
for name in labelName:
    data = np.load("data/%s.npy" %(name)) # Dimension M * 11, (第一组bowl,M=2666)
    label = np.zeros((data.shape[0], 1), dtype=np.int32) # Dimension M * 1
    label += count
    data = np.concatenate((data, label), axis=-1) # Dimension M * 12
    if count == 0:
        rawDataSets = data.copy()
    else:
        rawDataSets = np.concatenate((rawDataSets, data), axis=0)
    count += 1

# rawDataSets Dimension 21447 * 12
np.random.shuffle(rawDataSets)

totalCount = rawDataSets.shape[0] 
trainingCount = int(totalCount * trainingRatio) # must be 21447 ,rawDataSets.shape[1], must be 12
print(trainingCount)

# np.random.shuffle之后，就是按照比例，前80% 是training,后20%是validating
trainingData = torch.from_numpy(rawDataSets[0:trainingCount, 0:-1]).to(dtype=torch.float32).to(device)
trainingLabel = torch.from_numpy(rawDataSets[0:trainingCount, -1]).to(dtype=torch.long).to(device)
validatingData = torch.from_numpy(rawDataSets[trainingCount:, 0:-1]).to(dtype=torch.float32).to(device)
validatingLabel = torch.from_numpy(rawDataSets[trainingCount:, -1]).to(dtype=torch.long).to(device)

trainingDataSet = TensorDataset(trainingData, trainingLabel)
trainingDateLoader = DataLoader(trainingDataSet, batch_size=batchSize, shuffle=True)

validatingDataSet = TensorDataset(validatingData, validatingLabel)
validatingDataLoader = DataLoader(validatingDataSet, batch_size=batchSize, shuffle=True)


class FC(nn.Module):
    def __init__(self):
        super(FC, self).__init__()
        self.hidden1=nn.Sequential(
                nn.Linear(in_features=11,out_features=256,bias=True), # 20+5 / 20+11
                nn.Dropout(p = 0.2),
                nn.ReLU())
        self.hidden2=nn.Sequential(
                nn.Linear(in_features=256,out_features=128,bias=True),
                nn.ReLU())
        self.hidden3=nn.Sequential(
                nn.Linear(in_features=128,out_features=100,bias=True),
                nn.ReLU())
        self.hidden4=nn.Sequential(
                nn.Linear(in_features=100,out_features=10,bias=True))

    def forward(self,x):
        x=self.hidden1(x)
        x=self.hidden2(x)
        x=self.hidden3(x)
        output=self.hidden4(x)
        return output
    
net = FC()
net.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.0001)

iterr=[]
for i in range(100):
    iterr.append(i)

acc_val=[]

for epoch in range(100):
    statisticLoss = 0.0
    total = 0
    correct = 0
    # Training
    for i, (features, labels) in enumerate(trainingDateLoader):
        optimizer.zero_grad()
        outputs = net(features)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        statisticLoss += loss.item()

        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    trainingAcc = 100 * correct / total
    
    # Validating
    total = 0
    correct = 0
    with torch.no_grad():
        for i, (features, labels) in enumerate(validatingDataLoader):
            outputs = net(features)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0
# Epoch 79, Average Training Loss: 9.5458, Training Accuracy: 98.1377%, Validating Accuracy: 97.6371%
# Epoch 80, Average Training Loss: 9.2444, Training Accuracy: 98.0952%, Validating Accuracy: 97.8450%
# Epoch 81, Average Training Loss: 8.9252, Training Accuracy: 98.0763%, Validating Accuracy: 97.7694%
# Epoch 82, Average Training Loss: 9.1212, Training Accuracy: 98.0668%, Validating Accuracy: 97.8828%
# Epoch 83, Average Training Loss: 8.9056, Training Accuracy: 98.1283%, Validating Accuracy: 97.9017%
# Epoch 84, Average Training Loss: 8.8160, Training Accuracy: 98.0999%, Validating Accuracy: 97.9206%
# Epoch 85, Average Training Loss: 8.7252, Training Accuracy: 98.2134%, Validating Accuracy: 97.9206%
# Epoch 86, Average Training Loss: 8.5532, Training Accuracy: 98.2275%, Validating Accuracy: 97.6938%
# Epoch 87, Average Training Loss: 8.4905, Training Accuracy: 98.2181%, Validating Accuracy: 97.7883%
# Epoch 88, Average Training Loss: 8.8619, Training Accuracy: 98.0574%, Validating Accuracy: 97.7505%
# Epoch 89, Average Training Loss: 8.3684, Training Accuracy: 98.2748%, Validating Accuracy: 97.9962%
# Epoch 90, Average Training Loss: 8.3764, Training Accuracy: 98.2228%, Validating Accuracy: 98.1664%
# Epoch 91, Average Training Loss: 8.2856, Training Accuracy: 98.2181%, Validating Accuracy: 97.9962%
# Epoch 92, Average Training Loss: 7.9756, Training Accuracy: 98.2890%, Validating Accuracy: 97.9395%
# Epoch 93, Average Training Loss: 8.0446, Training Accuracy: 98.2606%, Validating Accuracy: 98.0718%
# Epoch 94, Average Training Loss: 8.3882, Training Accuracy: 98.2606%, Validating Accuracy: 98.0151%
# Epoch 95, Average Training Loss: 7.6826, Training Accuracy: 98.4024%, Validating Accuracy: 98.0151%
# Epoch 96, Average Training Loss: 8.0351, Training Accuracy: 98.2228%, Validating Accuracy: 98.2231%
# Epoch 97, Average Training Loss: 7.8312, Training Accuracy: 98.3835%, Validating Accuracy: 97.7316%
# Epoch 98, Average Training Loss: 7.7358, Training Accuracy: 98.3646%, Validating Accuracy: 97.9395%
# Epoch 99, Average Training Loss: 7.6907, Training Accuracy: 98.3504%, Validating Accuracy: 98.3176%
# Epoch 100, Average Training Loss: 7.5106, Training Accuracy: 98.3126%, Validating Accuracy: 97.9017%
# "\nplt.figure(1)\nplt.plot(iterr,acc_val)\nplt.title('Validating accuracy of sensor_part')\nplt.xlabel('epoch')\nplt.ylabel('training accuracy')\nplt.savefig('moving_sensor.png')\nplt.show()\n"

# %%
a=np.load("data/zero.npy")
print(a.shape)
print(a[0])
# Out:
# (2617, 11)
# [-0.8815332   0.13792245 -0.35283038 -0.34682727 -0.63621396  0.86147
#   0.9255241  -1.3825581   1.2934408  -0.8361659   1.2989041 ]
